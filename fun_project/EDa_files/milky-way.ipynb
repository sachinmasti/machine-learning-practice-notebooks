# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import mplcyberpunk
from warnings import filterwarnings
filterwarnings('ignore')

# %%
df = sns.load_dataset('titanic')

# %%
df.head()

# %%
df.describe()

# %%
df.shape

# %%
df.info()

# %%
import missingno as msno

# %% [markdown]
# <span style='color:pink'> there is not any pattern in missing values. </span>

# %%
matrix(df,color=[0.20,0,.30])
plt.title('missing values pattern',color='red',fontsize=(20))

# %%
msno.heatmap(df,figsize=(8,6))

# %%
msno.dendrogram(df)

# %%
df.sample(4)

# %%
print(df[(df['sex'] =='female')& (df['alive'] =='yes')].shape)
print(df[(df['sex']=='male') & (df['alive']=='yes')].shape)
# Out:
# (233, 15)
# (109, 15)

# %%
print(df[(df['sex']=='female') & (df['alive'] == 'no')].shape)
print(df[(df['sex'] =='male')& (df['alive'] =='no')].shape)
# Out:
# (81, 15)
# (468, 15)

# %%
female = 233+81
male = 109+468
print(female+male)

# %% [markdown]
# <span style='color:pink'> out of 334 females, 81 are died and percentage of total females alive is 75% females are alive.</span>

# %% [markdown]
# <span style='color:pink'> out of 577 males, 468 are died. and percentage of total male die is 81%.<span>

# %%
df['sex'].value_counts(normalize=True) * 100

# %%
df['alive'].value_counts(normalize=True) * 100

# %%
pd.crosstab(df['sex'],df['alive'],normalize='index') * 100
# Out:
# alive          no        yes
# sex
# female  25.796178  74.203822
# male    81.109185  18.890815

# %%
counts = df['sex'].value_counts()

# Man lijiye categories 'male' aur 'female' likhi hain
male_to_female_ratio = counts['male'] / counts['female']

print(f"Har 1 Female par {male_to_female_ratio:.2f} Males hain")
# Out:
# Har 1 Female par 1.84 Males hain

# %%
count = df['alive'].value_counts()

alive_ratio = count['no'] / count['yes']
alive_ratio
# Out:
# np.float64(1.605263157894737)

# %%
df['alive'].size

# %%
total = df['alive'].size

death_fraction = count['no'] / total

ratio = death_fraction * 5
print(f'{ratio:.0f} people are died out of 5')

# %%
total_females = df[(df['sex']=='female')].shape[0]

dead_females = df[(df['sex'] =='female') & (df['alive'] =='no')].shape[0]

fraction = masti / sachin

ratio = fraction * 5

print(f'{ratio:.2f} females are diet out of 5 females')

# %%
import plotly.express as px


fig = px.pie(values=size,names=labels,color=colors)
plt.tight_layout()
fig.show()

# %%
labels = ['Alive_females','dead_females']
size = [dead_females,total_females - dead_females]
colors = ['#6db6e3','#93de8a']

plt.pie(size,labels=labels,colors=colors,startangle=90,autopct='%.1f%%')
plt.title('dead females and total females')
plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.groupby('sex')['fare'].sum().reset_index()
# Out:
#       sex        fare
# 0  female  13966.6628
# 1    male  14727.2865

# %%
sns.boxplot(x='alive', y='fare', data=df)
# Out:
# <Axes: xlabel='alive', ylabel='fare'>

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %%
bar = sns.histplot(df['age'], kde=True,color='r',line_kws={'color':'blue'})
mplcyberpunk.add_bar_gradient(bars=bar.containers[0])

# %%
pd.crosstab(df['pclass'], df['alive'], normalize='index')
# Out:
# alive         no       yes
# pclass
# 1       0.370370  0.629630
# 2       0.527174  0.472826
# 3       0.757637  0.242363
